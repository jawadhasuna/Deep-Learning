# %% [markdown]
# # Jawad Hassan
# # 2230-0035
# # BS AI
# # ANN

# %% [markdown]
# # Lab 04

# %%
#libraries:
import numpy
import pandas
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.utils import to_categorical

# %%
#activity:
iris=load_iris()
x=iris.data
y=iris.target
print(x.shape)
print(y.shape)
scale=StandardScaler()
xscale=scale.fit_transform(x)
yencode=to_categorical(y)
xtrain,xtest,ytrain,ytest=train_test_split(xscale,yencode,test_size=0.2,random_state=42)
model=Sequential()
model.add(Dense(units=16,activation='relu',input_dim=4))
model.add(Dense(units=8,activation='relu'))
model.add(Dense(units=3,activation='softmax'))
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
history=model.fit(xtrain,ytrain,epochs=50,batch_size=8,validation_split=0.2)
loss,accuracy=model.evaluate(xtest,ytest)
print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}")
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# (150, 4)
# (150,)
# Epoch 1/50
# /Users/macbook/Desktop/env/lib/python3.9/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.2146 - loss: 1.1260 - val_accuracy: 0.1250 - val_loss: 1.1165
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2329 - loss: 1.0952 - val_accuracy: 0.2500 - val_loss: 1.0782
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3518 - loss: 1.0602 - val_accuracy: 0.2917 - val_loss: 1.0429
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3101 - loss: 1.0344 - val_accuracy: 0.2917 - val_loss: 1.0057
# Epoch 5/50
# ...

# %%
#task1-change hidden layers
# 16,8
model=Sequential()
model.add(Dense(units=16,activation='relu',input_dim=4))
model.add(Dense(units=8,activation='relu'))
model.add(Dense(units=3,activation='softmax'))
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
history=model.fit(xtrain,ytrain,epochs=50,batch_size=8,validation_split=0.2)
loss,accuracy=model.evaluate(xtest,ytest)
print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}")
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')   
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')     
plt.legend(['Train', 'Validation'], loc='upper left')   
plt.show()
# Out:
# Epoch 1/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.2443 - loss: 1.2160 - val_accuracy: 0.5417 - val_loss: 1.0356
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2838 - loss: 1.1236 - val_accuracy: 0.5417 - val_loss: 0.9595
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2887 - loss: 1.0765 - val_accuracy: 0.5833 - val_loss: 0.8966
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3426 - loss: 0.9869 - val_accuracy: 0.5833 - val_loss: 0.8391
# Epoch 5/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3138 - loss: 0.9428 - val_accuracy: 0.6250 - val_loss: 0.7931
# Epoch 6/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3658 - loss: 0.9049 - val_accuracy: 0.6667 - val_loss: 0.7495
# Epoch 7/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3982 - loss: 0.8770 - val_accuracy: 0.7917 - val_loss: 0.7156
# Epoch 8/50
# ...

# %%
# 8,4
model=Sequential()
model.add(Dense(units=16,activation='relu',input_dim=4))
model.add(Dense(units=8,activation='relu'))
model.add(Dense(units=3,activation='softmax'))
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
history=model.fit(xtrain,ytrain,epochs=50,batch_size=8,validation_split=0.2)
loss,accuracy=model.evaluate(xtest,ytest)
print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}")
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')   
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')     
plt.legend(['Train', 'Validation'], loc='upper left')   
plt.show()
# Out:
# Epoch 1/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.2793 - loss: 1.1751 - val_accuracy: 0.2500 - val_loss: 1.3252
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2301 - loss: 1.1904 - val_accuracy: 0.2500 - val_loss: 1.2511
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3012 - loss: 1.1099 - val_accuracy: 0.2500 - val_loss: 1.1972
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2696 - loss: 1.1469 - val_accuracy: 0.2917 - val_loss: 1.1479
# Epoch 5/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4092 - loss: 1.0422 - val_accuracy: 0.2917 - val_loss: 1.1194
# Epoch 6/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3773 - loss: 1.0421 - val_accuracy: 0.2917 - val_loss: 1.0901
# Epoch 7/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2867 - loss: 1.0510 - val_accuracy: 0.2917 - val_loss: 1.0655
# Epoch 8/50
# ...

# %%
# 32,16
model=Sequential()
model.add(Dense(units=32,activation='relu',input_dim=4))
model.add(Dense(units=16,activation='relu'))
model.add(Dense(units=3,activation='softmax'))
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
history=model.fit(xtrain,ytrain,epochs=50,batch_size=8,validation_split=0.2)
loss,accuracy=model.evaluate(xtest,ytest)
print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}")
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')   
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')     
plt.legend(['Train', 'Validation'], loc='upper left')   
plt.show()  
#best accuracy is with 16,8 hidden layers.
# Out:
# Epoch 1/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.2578 - loss: 1.4792 - val_accuracy: 0.2083 - val_loss: 1.1562
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2658 - loss: 1.3474 - val_accuracy: 0.4583 - val_loss: 0.9824
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3427 - loss: 1.1408 - val_accuracy: 0.5417 - val_loss: 0.8628
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3902 - loss: 0.9828 - val_accuracy: 0.5833 - val_loss: 0.7702
# Epoch 5/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4004 - loss: 0.9210 - val_accuracy: 0.7083 - val_loss: 0.6963
# Epoch 6/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6593 - loss: 0.7817 - val_accuracy: 0.7917 - val_loss: 0.6311
# Epoch 7/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7648 - loss: 0.7184 - val_accuracy: 0.7917 - val_loss: 0.5782
# Epoch 8/50
# ...

# %%
#task2- relu to tanh
model=Sequential()
model.add(Dense(units=16,activation='tanh',input_dim=4))
model.add(Dense(units=8,activation='tanh'))
model.add(Dense(units=3,activation='softmax'))
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
history=model.fit(xtrain,ytrain,epochs=50,batch_size=8,validation_split=0.2)
loss,accuracy=model.evaluate(xtest,ytest)
print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}")
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')   
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')     
plt.legend(['Train', 'Validation'], loc='upper left')   
plt.show()
# Out:
# Epoch 1/50
# /Users/macbook/Desktop/env/lib/python3.9/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.5182 - loss: 1.0676 - val_accuracy: 0.5000 - val_loss: 1.0235
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5452 - loss: 0.9458 - val_accuracy: 0.5000 - val_loss: 0.9219
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6233 - loss: 0.7940 - val_accuracy: 0.5000 - val_loss: 0.8356
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6420 - loss: 0.7280 - val_accuracy: 0.5833 - val_loss: 0.7611
# Epoch 5/50
# ...

# %%
#task3: epochs to 100
model=Sequential()
model.add(Dense(units=16,activation='relu',input_dim=4))
model.add(Dense(units=8,activation='relu'))
model.add(Dense(units=3,activation='softmax'))
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
history=model.fit(xtrain,ytrain,epochs=100,batch_size=8,validation_split=0.2)
loss,accuracy=model.evaluate(xtest,ytest)
print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}")
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')   
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')     
plt.legend(['Train', 'Validation'], loc='upper left')   
plt.show()  
#best accuracy is with 100 epochs.
# Out:
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.3817 - loss: 1.1640 - val_accuracy: 0.2917 - val_loss: 1.1510
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3332 - loss: 1.0774 - val_accuracy: 0.4167 - val_loss: 1.0751
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4294 - loss: 1.0303 - val_accuracy: 0.5417 - val_loss: 1.0031
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6247 - loss: 0.9433 - val_accuracy: 0.5833 - val_loss: 0.9402
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6794 - loss: 0.8999 - val_accuracy: 0.6667 - val_loss: 0.8872
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7012 - loss: 0.8039 - val_accuracy: 0.7500 - val_loss: 0.8371
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6013 - loss: 0.7964 - val_accuracy: 0.7500 - val_loss: 0.7971
# Epoch 8/100
# ...
